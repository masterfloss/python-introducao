# %%
#Os tuplos são idênticos às listas, mas não podem ser modificados
#São designados imutáveis

novas_compras = ("bananas", "feijão","arroz")
print (novas_compras[1])
novas_compras[0]="maçã"
# Out:
# feijão
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-31c8f7e09d6d> in <module>()
#       2 novas_compras = ("bananas", "feijão","arroz")
#       3 print (novas_compras[1])
# ----> 4 novas_compras[0]="maçã"
#
# TypeError: 'tuple' object does not support item assignment
